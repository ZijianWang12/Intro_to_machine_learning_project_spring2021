# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#load the data
'''from google.colab import files
uploaded = files.upload()'''
# Out:
# 'from google.colab import files\nuploaded = files.upload()'

# %%
'''uploaded = files.upload()'''
# Out:
# 'uploaded = files.upload()'

# %%
#get df dropped ID
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
train_df=train_df.drop('Id',axis=1)
test_df=test_df.drop('Id',axis=1)

# %%
#heatmap
import seaborn as sns
import matplotlib.pyplot as plt
plt.subplots(figsize=(45, 30))
sns.heatmap(train_df.corr('pearson').abs(), annot = True, square = True, linewidths = 0.4)
plt.show()

# %%
#boxplot of 'OverallQuality' vs 'SalePrice'
figure, ax = plt.subplots( figsize = (15,10))
sns.boxplot(data=train_df, x = 'OverallQual', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
#Distribution of SalePrice
ax = sns.distplot(train_df['SalePrice'])

# %%
train_df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
test_df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             20       RH         80.0    11622   Pave   NaN      Reg
# 1             20       RL         81.0    14267   Pave   NaN      IR1
# 2             60       RL         74.0    13830   Pave   NaN      IR1
# 3             60       RL         78.0     9978   Pave   NaN      IR1
# 4            120       RL         43.0     5005   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1454         160       RM         21.0     1936   Pave   NaN      Reg
# 1455         160       RM         21.0     1894   Pave   NaN      Reg
# 1456          20       RL        160.0    20000   Pave   NaN      Reg
# 1457          85       RL         62.0    10441   Pave   NaN      Reg
# 1458          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# ...
